# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
import pickle
df=pd.read_csv("book.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  630000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color="red",marker="+")

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(df[['area']],df.price)
reg.predict([[3300]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([618441.78082192])

# %%
reg.coef_
# Out:
# array([122.0890411])

# %%
reg.intercept_
# Out:
# 215547.9452054794

# %%
122.0890411*3300+215547.9452054794
# Out:
# 618441.7808354794

# %%
# %matplotlib inline
plt.xlabel("area",fontsize=20)
plt.ylabel("price",fontsize=20)
plt.scatter(df.area, df.price, color="red", marker="+")
plt.plot(df.area, reg.predict(df[["area"]]), color="blue")

# %%
d=pd.read_csv("areas.csv")
d
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
p=reg.predict(d)
p
# Out:
# array([ 337636.98630137,  398681.50684932,  496352.73972603,
#         647743.15068493,  718554.79452055,  772273.97260274,
#         885816.78082192,  637976.02739726,  795470.89041096,
#         496352.73972603, 1314349.31506849, 1265513.69863014,
#        1082380.1369863 ])

# %%
d['prices']=p
d.to_csv("prediction.csv",index=False)
